# %%
# PROCEDEMOS A DESCARGAR EL DATASET DE LOS FUTBOLISTAS DEL FIFA 23

# %%
import pandas as pd

data_players = pd.read_csv("Fifa_23_Players_Data.csv")

# %%
# REALIZAMOS UNA FUNCION PARA EXTRAER LA INFORMACIÓN GENERAL DEL DATAFRAME

# %%
def informe(x):
    print("Información del DataFrame:")
    print(x.info())
    print("Descripción estadística:")
    print(x.describe())
    print("Valores nulos:")
    print(x.isnull().sum())
    print("Tipos de datos:")
    print(x.dtypes)
    
    print("Primeras 5 filas:")
    print(x.head())
    print("Últimas 5 filas:")
    print(x.tail())
    print("Forma del DataFrame:")
    print(x.shape)
    print("columnas")
    print(x.columns)
    print("numericos")
    print(x.select_dtypes(include=["number"]).columns)

# %%
informe(data_players)
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known As                     18539 non-null  object
#  1   Full Name                    18539 non-null  object
#  2   Overall                      18539 non-null  int64
#  3   Potential                    18539 non-null  int64
#  4   Value(in Euro)               18539 non-null  int64
#  5   Positions Played             18539 non-null  object
#  6   Best Position                18539 non-null  object
#  7   Nationality                  18539 non-null  object
#  8   Image Link                   18539 non-null  object
#  9   Age                          18539 non-null  int64
#  10  Height(in cm)                18539 non-null  int64
#  11  Weight(in kg)                18539 non-null  int64
# ...

# %%
def datos(x):
    print("datos nulos")
    print(x.isnull().sum())
    print("datos totales")
    print(x.count())   
    print("porcentaje de nulos")
    print(x.isnull().sum() / x.shape[0]*100)
    print("datos duplicados")
    print(x.duplicated().sum())
    print(x.duplicated().any())

# %%
datos(data_players)
# Out:
# datos nulos
# Known As          0
# Full Name         0
# Overall           0
# Potential         0
# Value(in Euro)    0
#                  ..
# RWB Rating        0
# LB Rating         0
# CB Rating         0
# RB Rating         0
# GK Rating         0
# Length: 89, dtype: int64
# datos totales
# Known As          18539
# Full Name         18539
# Overall           18539
# Potential         18539
# Value(in Euro)    18539
#                   ...
# RWB Rating        18539
# LB Rating         18539
# CB Rating         18539
# RB Rating         18539
# GK Rating         18539
# Length: 89, dtype: int64
# porcentaje de nulos
# Known As          0.0
# Full Name         0.0
# Overall           0.0
# Potential         0.0
# Value(in Euro)    0.0
#                  ...
# RWB Rating        0.0
# LB Rating         0.0
# CB Rating         0.0
# RB Rating         0.0
# GK Rating         0.0
# Length: 89, dtype: float64
# datos duplicados
# 119
# True

# %%
# DE ESTE PRIMER PANTALLAZO PODEMOS CONFIRMAR QUE NO HAY VALORES NULLOS EN EL DATASET.

# %%
# PROCEDEREMOS A ELIMNAR LAS COLUMNAS QUE NO NECESITEMOS PARA ESTE ANALISIS Y MODIFICAR EL FORMATO DE AQUELLAS QUE QUEDARÁN EN EL DF.

# %%
data_players.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
def drop_columns (df, columns):
    df.drop(columns, axis=1, inplace=True)

# %%
columns_drop = ['Known As', 'Potential', 'Positions Played','Image Link', 'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats','Release Clause','Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan', 'Preferred Foot', 'Weak Foot Rating', 'Skill Moves', 'International Reputation','National Team Image Link', 'National Team Position', 'National Team Jersey Number', 'Attacking Work Rate', 'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
       'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
       'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeper Diving', 'Goalkeeper Handling', ' GoalkeeperKicking', 'Goalkeeper Positioning', 'Goalkeeper Reflexes', 'ST Rating',
       'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating','GK Rating']

drop_columns(data_players, columns_drop)

# %%
columns_drop = ["Overall", "Wage(in Euro)", "Club Position"]

drop_columns(data_players, columns_drop)

# %%
data_players.columns = data_players.columns.str.lower().str.replace(" ", "_")

# %%
data_players.head()
# Out:
#             full_name  value(in_euro) best_position nationality  age  \
# 0        Lionel Messi        54000000           CAM   Argentina   35
# 1       Karim Benzema        64000000            CF      France   34
# 2  Robert Lewandowski        84000000            ST      Poland   33
# 3     Kevin De Bruyne       107500000            CM     Belgium   31
# 4       Kylian Mbappé       190500000            ST      France   23
#
#              club_name national_team_name
# 0  Paris Saint-Germain          Argentina
# 1       Real Madrid CF             France
# 2         FC Barcelona             Poland
# 3      Manchester City            Belgium
# 4  Paris Saint-Germain             France

# %%
# PROCEDEMOS A DESCARGAR EL DATASET DEL RANKING FIFA A TRAVES DE UNA API

# %%
import requests

url = "https://world-football-ranking.p.rapidapi.com/current-ranking.php"

headers = {
	"x-rapidapi-key": "7bd4fcc4f2mshd98d9b81c1742b4p1cbf72jsn8816d26fd89d",
	"x-rapidapi-host": "world-football-ranking.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"date":"19 January, 2026","ranking":[{"rank":1,"flag":"https:\\/\\/api.fifa.com\\/api\\/v3\\/picture\\/flags-sq-2\\/ESP","name":"Spain","previous_rank":1,"points":1877.18,"previous_points":1877.18,"confederation":"UEFA"},{"rank":2,"flag":"https:\\/\\/api.fifa.com\\/api\\/v3\\/picture\\/flags-sq-2\\/ARG","name":"Argentina","previous_rank":2,"points":1873.33,"previous_points":1873.33,"confederation":"CONMEBOL"},{"rank":3,"flag":"https:\\/\\/api.fifa.com\\/api\\/v3\\/picture\\/flags-sq-2\\/FRA","name":"France","previous_rank":3,"points":1870,"previous_points":1870,"confederation":"UEFA"},{"rank":4,"flag":"https:\\/\\/api.fifa.com\\/api\\/v3\\/picture\\/flags-sq-2\\/ENG","name":"England","previous_rank":4,"points":1834.12,"previous_points":1834.12,"confederation":"UEFA"},{"rank":5,"flag":"https:\\/\\/api.fifa.com\\/api\\/v3\\/picture\\/flags-sq-2\\/BRA","name":"Brazil","previous_rank":5,"points":1760.46,"previous_points":1760.46,"confederation":"CONMEBOL"},{"rank":6,"flag":"https:\\/\
# ...

# %%
info = response.json()
info
# Out:
# {'date': '19 January, 2026',
#  'ranking': [{'rank': 1,
#    'flag': 'https://api.fifa.com/api/v3/picture/flags-sq-2/ESP',
#    'name': 'Spain',
#    'previous_rank': 1,
#    'points': 1877.18,
#    'previous_points': 1877.18,
#    'confederation': 'UEFA'},
#   {'rank': 2,
#    'flag': 'https://api.fifa.com/api/v3/picture/flags-sq-2/ARG',
#    'name': 'Argentina',
#    'previous_rank': 2,
#    'points': 1873.33,
#    'previous_points': 1873.33,
#    'confederation': 'CONMEBOL'},
#   {'rank': 3,
#    'flag': 'https://api.fifa.com/api/v3/picture/flags-sq-2/FRA',
#    'name': 'France',
#    'previous_rank': 3,
#    'points': 1870,
#    'previous_points': 1870,
#    'confederation': 'UEFA'},
#   {'rank': 4,
#    'flag': 'https://api.fifa.com/api/v3/picture/flags-sq-2/ENG',
#    'name': 'England',
#    'previous_rank': 4,
#    'points': 1834.12,
#    'previous_points': 1834.12,
#    'confederation': 'UEFA'},
#   {'rank': 5,
# ...

# %%
type(info)
# Out:
# dict

# %%
#UNA VEZ DESCARGADA LA API PROCEDOMOS A GENERAR EL DATA FRAME

# %%
info["ranking"][0]
# Out:
# {'rank': 1,
#  'flag': 'https://api.fifa.com/api/v3/picture/flags-sq-2/ESP',
#  'name': 'Spain',
#  'previous_rank': 1,
#  'points': 1877.18,
#  'previous_points': 1877.18,
#  'confederation': 'UEFA'}

# %%
ranking_list = info["ranking"]

# %%
type(ranking_list)
# Out:
# list

# %%
import pandas as pd

data_ranking = pd.DataFrame(ranking_list)

# %%
informe(data_ranking)
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             210 non-null    float64
#  1   flag             211 non-null    object
#  2   name             211 non-null    object
#  3   previous_rank    210 non-null    float64
#  4   points           211 non-null    float64
#  5   previous_points  211 non-null    float64
#  6   confederation    211 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 11.7+ KB
# None
# Descripción estadística:
#              rank  previous_rank       points  previous_points
# count  210.000000     210.000000   211.000000       211.000000
# mean   105.500000     105.500000  1229.827441      1224.810664
# std     60.765944      60.765944   277.179238       286.855521
# min      1.000000       1.000000   726.030000         0.000000
# ...

# %%
# AVANZAMOS CON LA LIMPIEZA QUITANDO LAS COLUMNAS QUE NO NECESITAREMOS PARA ESTE ANALISIS

# %%
data_ranking.columns
# Out:
# Index(['rank', 'flag', 'name', 'previous_rank', 'points', 'previous_points',
#        'confederation'],
#       dtype='object')

# %%
columns_drop = ['flag', 'previous_rank', 'previous_points']

drop_columns(data_ranking, columns_drop)

# %%
data_ranking.head()
# Out:
#    rank national_team_name   points confederation
# 0   1.0              Spain  1877.18          UEFA
# 1   2.0          Argentina  1873.33      CONMEBOL
# 2   3.0             France  1870.00          UEFA
# 3   4.0            England  1834.12          UEFA
# 4   5.0             Brazil  1760.46      CONMEBOL

# %%
#MODIFICAMOS EL NOMBRE DE LA COLUMNA NAME DE DATA_RANKING PARA PODER HACER EL MERGE

# %%
data_ranking.rename(columns= {'name': 'national_team_name'}, inplace=True)

# %%
#UNA VEZ REALIZADA LA LIMPIEZA DE AMBOS DATASETS PROCEDEMOS A UNIRLOS, LO UNIMOS CON UN LEFT PORQUE NO QUEREMOS PERDER LOS DATOS DE LOS JUGADORES QUE NO ESTEN DENTRO DE LAS SELECCIONES TOP 20

# %%
def union_df (df1,df2):
    df_union = pd.merge(df1,df2,on=["national_team_name"],how='left')
    return df_union

# %%
df_union = union_df(data_players,data_ranking)

# %%
df_union
# Out:
#                 full_name  value(in_euro) best_position          nationality  \
# 0            Lionel Messi        54000000           CAM            Argentina
# 1           Karim Benzema        64000000            CF               France
# 2      Robert Lewandowski        84000000            ST               Poland
# 3         Kevin De Bruyne       107500000            CM              Belgium
# 4           Kylian Mbappé       190500000            ST               France
# ...                   ...             ...           ...                  ...
# 18534      Darren Collins          110000           CAM  Republic of Ireland
# 18535        Dejiang Yang           90000           CDM             China PR
# 18536         Liam Mullan          130000            RM     Northern Ireland
# 18537    Daithí McCallion          100000            CB  Republic of Ireland
# 18538         Nabin Rabha           60000            LB                India
#
# ...
